# %%
# !spark-submit --master local[*] \
  --jars /workspace/lib/iceberg-spark-runtime-3.5_2.12-1.5.0.jar,/workspace/lib/iceberg-aws-1.5.0.jar,/workspace/lib/nessie-spark-extensions-3.5_2.12-0.78.0.jar \
  --conf spark.sql.extensions=org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions,org.projectnessie.spark.extensions.NessieSparkSessionExtensions \
  --conf spark.sql.catalog.nessie=org.apache.iceberg.spark.SparkCatalog \
  --conf spark.sql.catalog.nessie.catalog-impl=org.apache.iceberg.nessie.NessieCatalog \
  --conf spark.sql.catalog.nessie.uri=http://nessie-server:19120 \
  --packages org.apache.iceberg:iceberg-aws-bundle:1.5.0,software.amazon.awssdk:s3:2.20.42 \
  create_table_csv.py
# Out:
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# org.apache.iceberg#iceberg-aws-bundle added as a dependency
# software.amazon.awssdk#s3 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-49a10be2-c3d7-4faa-9fa3-61325d9dd510;1.0
# 	confs: [default]
# 	found org.apache.iceberg#iceberg-aws-bundle;1.5.0 in central
# 	found software.amazon.awssdk#s3;2.20.42 in central
# 	found software.amazon.awssdk#aws-xml-protocol;2.20.42 in central
# 	found software.amazon.awssdk#aws-query-protocol;2.20.42 in central
# 	found software.amazon.awssdk#protocol-core;2.20.42 in central
# 	found software.amazon.awssdk#sdk-core;2.20.42 in central
# 	found software.amazon.awssdk#annotations;2.20.42 in central
# 	found software.amazon.awssdk#http-client-spi;2.20.42 in central
# ...
